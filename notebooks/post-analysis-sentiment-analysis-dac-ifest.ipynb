# %% [markdown]
# # Libraries

# %%
# !pip install bertopic
from IPython.display import clear_output
clear_output()

# %%
# Core
import pandas as pd
import numpy as np

# Topic Modeling
from bertopic import BERTopic
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP
from sentence_transformers import SentenceTransformer
from bertopic.representation import KeyBERTInspired
from bertopic.representation import MaximalMarginalRelevance
from bertopic.representation import TextGeneration
import random
# Out:
# /opt/conda/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /opt/conda/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /opt/conda/lib/python3.10/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /opt/conda/lib/python3.10/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %% [markdown]
# # Data Preparation

# %% [markdown]
# **1. Data Collection**

# %%
train = pd.read_csv('/kaggle/input/dac-itfest-processed/train-processed.csv')
test = pd.read_csv('/kaggle/input/dac-ifest-predicted/test-predicted-slang-indobertweet.csv')

# %%
data = pd.concat([train,test],ignore_index=True)

# %% [markdown]
# # EDA

# %% [markdown]
# # BERTopic Analysis

# %%
# Mengelompokkan semua data
fear_df = data[data['label'] == 'fear']
joy_df = data[data['label'] == 'joy']
anger_df = data[data['label'] == 'anger']
love_df = data[data['label'] == 'love']
sad_df = data[data['label'] == 'sadness']

# Mengelompokkan test data
fear_test = test[test['label'] == 'fear']
joy_test = test[test['label'] == 'joy']
anger_test = test[test['label'] == 'anger']
love_test = test[test['label'] == 'love']
sad_test = test[test['label'] == 'sadness']

# %% [markdown]
# ### Fear Analysis

# %% [markdown]
# **Define Model**

# %%
docs = fear_df['tweet']

# %%
# Prevent Stochastic Behavior (Mencegah Hasil Berubah-ubah setiap Menjalankan)
umap_model = UMAP(random_state = 42)

# Model representasi untuk topik
representation_model = KeyBERTInspired()

# %%
# Define topic model
topic_model = BERTopic(
    umap_model=umap_model,
    language="indonesian", 
    representation_model=representation_model,
    verbose = True, 
    nr_topics="auto",
    min_topic_size = 3
)

# %% [markdown]
# **Clustering**

# %%
# Train
topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading (…)0fe39/.gitattributes:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)83e900fe39/README.md:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading (…)e900fe39/config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading unigram.json:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Downloading (…)900fe39/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/26 [00:00<?, ?it/s]
# 2023-09-04 01:14:41,764 - BERTopic - Transformed documents to Embeddings
# 2023-09-04 01:14:54,149 - BERTopic - Reduced dimensionality
# 2023-09-04 01:14:54,205 - BERTopic - Clustered reduced embeddings
# 2023-09-04 01:14:56,577 - BERTopic - Reduced number of topics from 3 to 3

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                             Name  \
# 0      0    785  0_takut_kenapa_perasaan_sendiri
# 1      1     11     1_sholat_gereja_setan_hadist
# 2      2      7   2_pasien_pasiennya_medis_mohon
#
#                                       Representation  \
# 0  [takut, kenapa, perasaan, sendiri, merasa, tap...
# 1  [sholat, gereja, setan, hadist, paroki, godaan...
# 2  [pasien, pasiennya, medis, mohon, perintahkan,...
#
#                                  Representative_Docs
# 0  [teman-teman aku lagi deg degan parah, takut t...
# 1  [tidak disemua tempat kita boleh melaksanakan ...
# 2  [aku tidak salah bila mohon pada , segera peri...

# %%
topic_model.get_document_info(docs)
# Out:
#                                               Document  Topic  \
# 0    lebih menyeramkan kalau punya grup wa keluarga...      1
# 1    iya bagaimana. diajak jalan saja gatau kenapa ...      0
# 2    aku dulu nemu ig nya dia. pas dia lagi lihat c...      0
# 3    entah gatau kenapa, semakin bertambahnya umur ...      0
# 4    tidak disemua tempat kita boleh melaksanakan s...      1
# ..                                                 ...    ...
# 798  bicara-bicara doa restu orang tua itu emang gi...      0
# 799  desain razer mirip banget mbp. bahkan lbh mode...      0
# 800  ketika kamu merasa seperti kamu terjebak dalam...      0
# 801          saat pintu berderik-derik terbuka sendiri      0
# 802  tapi tentunya secara ini bekasi ada hal-hal ya...      0
#
#                                 Name  \
# 0       1_sholat_gereja_setan_hadist
# 1    0_takut_kenapa_perasaan_sendiri
# 2    0_takut_kenapa_perasaan_sendiri
# 3    0_takut_kenapa_perasaan_sendiri
# 4       1_sholat_gereja_setan_hadist
# ..                               ...
# 798  0_takut_kenapa_perasaan_sendiri
# 799  0_takut_kenapa_perasaan_sendiri
# 800  0_takut_kenapa_perasaan_sendiri
# 801  0_takut_kenapa_perasaan_sendiri
# 802  0_takut_kenapa_perasaan_sendiri
#
#                                         Representation  \
# 0    [sholat, gereja, setan, hadist, paroki, godaan...
# 1    [takut, kenapa, perasaan, sendiri, merasa, tap...
# 2    [takut, kenapa, perasaan, sendiri, merasa, tap...
# 3    [takut, kenapa, perasaan, sendiri, merasa, tap...
# 4    [sholat, gereja, setan, hadist, paroki, godaan...
# ..                                                 ...
# 798  [takut, kenapa, perasaan, sendiri, merasa, tap...
# 799  [takut, kenapa, perasaan, sendiri, merasa, tap...
# 800  [takut, kenapa, perasaan, sendiri, merasa, tap...
# 801  [takut, kenapa, perasaan, sendiri, merasa, tap...
# 802  [takut, kenapa, perasaan, sendiri, merasa, tap...
#
#                                    Representative_Docs  \
# 0    [tidak disemua tempat kita boleh melaksanakan ...
# 1    [teman-teman aku lagi deg degan parah, takut t...
# 2    [teman-teman aku lagi deg degan parah, takut t...
# 3    [teman-teman aku lagi deg degan parah, takut t...
# 4    [tidak disemua tempat kita boleh melaksanakan ...
# ..                                                 ...
# 798  [teman-teman aku lagi deg degan parah, takut t...
# 799  [teman-teman aku lagi deg degan parah, takut t...
# 800  [teman-teman aku lagi deg degan parah, takut t...
# 801  [teman-teman aku lagi deg degan parah, takut t...
# 802  [teman-teman aku lagi deg degan parah, takut t...
#
#                                            Top_n_words  Probability  \
# 0    sholat - gereja - setan - hadist - paroki - go...          1.0
# 1    takut - kenapa - perasaan - sendiri - merasa -...          1.0
# 2    takut - kenapa - perasaan - sendiri - merasa -...          1.0
# 3    takut - kenapa - perasaan - sendiri - merasa -...          1.0
# 4    sholat - gereja - setan - hadist - paroki - go...          1.0
# ..                                                 ...          ...
# 798  takut - kenapa - perasaan - sendiri - merasa -...          1.0
# 799  takut - kenapa - perasaan - sendiri - merasa -...          1.0
# 800  takut - kenapa - perasaan - sendiri - merasa -...          1.0
# 801  takut - kenapa - perasaan - sendiri - merasa -...          1.0
# 802  takut - kenapa - perasaan - sendiri - merasa -...          1.0
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                       True
# ..                       ...
# 798                    False
# 799                    False
# 800                    False
# 801                    False
# 802                    False
#
# [803 rows x 8 columns]

# %%
topic_model.visualize_barchart(title='Topic pada Undang-Undang')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="7509f252-b953-4ea4-b463-b814cf3d2ea4" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7509f252-b953-4ea4-b463-b814cf3d2ea4")) {                    Plotly.newPlot(                        "7509f252-b953-4ea4-b463-b814cf3d2ea4",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.40846896171569824,0.44156402349472046,0.4529775381088257,0.4559546709060669,0.5762276649475098],"y":["merasa  ","sendiri  ","perasaan  ","kenapa  ","takut  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.3590232729911804,0.44132107496261597,0.4807712435722351,0.5463786721229553,0.5757783651351929],"y":["paroki  ","hadist  ","setan  ","gereja  ","sholat  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.3249683082103729,0.33176547288894653,0.4753778576850891,0.5228453278541565,0.5409978032112122],"y":["perintahkan  ","mohon  ","medis  ","pasiennya  ","pasien  "],"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histo ...
